# %% [markdown]
# # Домашнее задание 1
# Захаров Савелий

# %% [markdown]
# ## Sleep Equation

# %%
import numpy as np # linear algebra 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# stats models: regression fitting
import statsmodels.formula.api as smf
# data visualization
import seaborn as sns

# %% [markdown]
# Загрузим данные их файла `sleep75.csv` и выведем размер датасета

# %%
df = pd.read_csv('/Users/saveliyzakharov/Downloads/Econometrica-master/python-notebooks/data-csv/sleep75.csv')
df.shape
# Out:
# (706, 34)

# %% [markdown]
# Выведем первые 5 наблюдения

# %%
df.head()
# Out:
#    age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0   32      0     1       0.0       0.0    12        0       0     1   3529
# 1   31      0     2       0.0       0.0    14     9500       1     1   2140
# 2   44      0     3       0.0       0.0    17    42500       1     1   4595
# 3   30      0     4       0.0       0.0    12    42500       1     1   3211
# 4   64      0     5       0.0       0.0    14     2500       1     1   4052
#
#    ...  spwrk75  totwrk  union  worknrm  workscnd  exper  yngkid  yrsmarr  \
# 0  ...        0    3438      0     3438         0     14       0       13
# 1  ...        0    5020      0     5020         0     11       0        0
# 2  ...        1    2815      0     2815         0     21       0        0
# 3  ...        1    3786      0     3786         0     12       0       12
# 4  ...        1    2580      0     2580         0     44       0       33
#
#       hrwage  agesq
# 0   7.070004   1024
# 1   1.429999    961
# 2  20.529997   1936
# 3   9.619998    900
# 4   2.750000   4096
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Пример 1 (sleep vs totwrk)
#
# построим диаграмму рассеяним **sleep vs totwrk** и вычислим параметры оптимальной прямой

# %%
sns.scatterplot(data=df, y='sleep', x='totwrk', color = 'C1')
# Out:
# <Axes: xlabel='totwrk', ylabel='sleep'>

# %% [markdown]
# постройте диаграмму рассеяним **sleep vs totwrk** с 'подогнанной' прямой

# %%
sns.regplot(data=df, y='sleep', x='totwrk', ci=None, line_kws={"color": "b"}, color = 'C1')
# Out:
# <Axes: xlabel='totwrk', ylabel='sleep'>

# %%
# подгонка прямой
fitted_line = smf.ols(formula='sleep~totwrk', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# Intercept    3586.38
# totwrk         -0.15
# dtype: float64

# %% [markdown]
# Найдем параметры без константы

# %%
# подгонка прямой
fitted_line = smf.ols(formula='sleep~-1+totwrk', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# totwrk    1.26
# dtype: float64

# %% [markdown]
# # Пример 2 (sleep vs age)
# построим диаграмму рассеяним sleep vs age и вычислим параметры оптимальной прямой

# %%
sns.scatterplot(data=df, y='sleep', x='age', color = "green")
# Out:
# <Axes: xlabel='age', ylabel='sleep'>

# %% [markdown]
# построим диаграмму рассеяним **sleep vs age** с 'подогнанной' прямой

# %%
sns.regplot(data=df, y='sleep', x='age', ci=None, line_kws={"color": "r"}, color = "g")
# Out:
# <Axes: xlabel='age', ylabel='sleep'>

# %%
# подгонка прямой
fitted_line = smf.ols(formula='sleep~age', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# Intercept    3128.91
# age             3.54
# dtype: float64

# %% [markdown]
# Найдем параметры без константы

# %%
# подгонка прямой
fitted_line = smf.ols(formula='sleep~-1+age', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# age    77.82
# dtype: float64

# %% [markdown]
# ## Пример 3 (sleep vs totwrk, totwrk^2)
#
# постройте диаграмму рассеяним **sleep vs totwrk** с 'подогнанной' параболой

# %%
sns.regplot(data=df, y='sleep', x='totwrk', ci=None, order=2, line_kws={"color": "b"}, color = "C1")
# Out:
# <Axes: xlabel='totwrk', ylabel='sleep'>

# %% [markdown]
# найти параметры оптимальной параболы **sleep на totwrk, totwrk^2**

# %%
# подгонка параболы
fitted_pol = smf.ols(formula='sleep~totwrk+I(totwrk**2)', data=df).fit()
# коэффициенты с округлением
fitted_pol.params.round(2)
# Out:
# Intercept         3523.59
# totwrk              -0.07
# I(totwrk ** 2)      -0.00
# dtype: float64

# %% [markdown]
# # Пример 4 (sleep vs age, age^2)
#
# постройте диаграмму рассеяним **sleep vs age** с 'подогнанной' параболой

# %%
sns.regplot(data=df, y='sleep', x='age', ci=None, order=2, line_kws={"color": "r"}, color = "g")
# Out:
# <Axes: xlabel='age', ylabel='sleep'>

# %% [markdown]
# найти параметры оптимальной параболы **sleep на age, age^2**

# %%
# подгонка параболы
fitted_pol = smf.ols(formula='sleep~age+I(age**2)', data=df).fit()
# коэффициенты с округлением
fitted_pol.params.round(2)
# Out:
# Intercept      3608.03
# age             -21.49
# I(age ** 2)       0.30
# dtype: float64

# %% [markdown]
# ## Пример 5 (sleep на totwrk & age)

# %%
# подгонка плоскости
fitted_plane = smf.ols(formula='sleep~totwrk+age', data=df).fit()
# коэффициенты с округлением
fitted_plane.params.round(2)
# Out:
# Intercept    3469.20
# totwrk         -0.15
# age             2.92
# dtype: float64
